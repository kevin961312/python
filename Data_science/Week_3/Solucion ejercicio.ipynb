# %%
import pandas as pd
import numpy as np

# %%
energy = pd.read_excel('Energy Indicators.xls', skiprows=17,skipfooter=38)
energy = energy.drop(energy.columns[[0,1]], axis=1)
energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
for col in energy:
    energy[col]=energy[col].replace('...',np.NaN)
energy['Energy Supply']*=1000000
energy['Country'] = energy['Country'].str.replace(r" \(.*\)","")
energy['Country'] = energy['Country'].str.replace(r"([0-9]+)$","")
energy['Country'] = energy['Country'].str.strip()
energy['Country'].replace("Republic of Korea","South Korea",inplace=True)
energy['Country'].replace("United States of America","United States",inplace=True)
energy['Country'].replace("United Kingdom of Great Britain and Northern Ireland","United Kingdom",inplace=True)
energy['Country'].replace("China, Hong Kong Special Administrative Region","Hong Kong",inplace=True)
energy = energy.set_index('Country')
rang = ['{}'.format(i) for i in range(2006,2016)]
user = ['Country Name']+rang
GPD = pd.read_csv('world_bank.csv',skiprows=4, usecols=user)
GPD = GPD.rename(columns={'Country Name':'Country'})
GPD['Country'].replace("Korea, Rep.","South Korea",inplace=True)
GPD['Country'].replace("Iran, Islamic Rep.","Iran",inplace=True)
GPD['Country'].replace("Hong Kong SAR, China","Hong Kong",inplace=True)
GPD = GPD.set_index('Country')
ScimEn = pd.read_excel('scimagojr-3.xlsx')
ScimEn = ScimEn.set_index('Country')
first_merge = pd.merge(energy,GPD,left_index=True, right_index=True,how='outer')
result = pd.merge(ScimEn,first_merge,left_index=True, right_index=True,how='outer')
result = result[result['Rank']<=15]
result.sort_values(by=['Rank'], inplace=True)
result
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                1.0   127050.0           126767.0   597237.0
# United States        2.0    96661.0            94747.0   792274.0
# Japan                3.0    30504.0            30287.0   223024.0
# United Kingdom       4.0    20944.0            20357.0   206091.0
# Russian Federation   5.0    18534.0            18301.0    34266.0
# Canada               6.0    17899.0            17620.0   215003.0
# Germany              7.0    17027.0            16831.0   140566.0
# India                8.0    15005.0            14841.0   128763.0
# France               9.0    13153.0            12973.0   130632.0
# South Korea         10.0    11983.0            11923.0   114675.0
# Italy               11.0    10964.0            10794.0   111850.0
# Spain               12.0     9428.0             9330.0   123336.0
# Iran                13.0     8896.0             8819.0    57470.0
# ...

# %%
energy = pd.read_excel('Energy Indicators.xls', skiprows=17,skipfooter=38)
energy = energy.drop(energy.columns[[0,1]], axis=1)
energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
for col in energy:
    energy[col]=energy[col].replace('...',np.NaN)
energy['Energy Supply']*=1000000
energy['Country'] = energy['Country'].str.replace(r" \(.*\)","")
energy['Country'] = energy['Country'].str.replace(r"([0-9]+)$","")
energy['Country'] = energy['Country'].str.strip()
energy['Country'].replace("Republic of Korea","South Korea",inplace=True)
energy['Country'].replace("United States of America","United States",inplace=True)
energy['Country'].replace("United Kingdom of Great Britain and Northern Ireland","United Kingdom",inplace=True)
energy['Country'].replace("China, Hong Kong Special Administrative Region","Hong Kong",inplace=True)
energy = energy.set_index('Country')
rang = ['{}'.format(i) for i in range(2006,2016)]
user = ['Country Name']+rang
GPD = pd.read_csv('world_bank.csv',skiprows=4, usecols=user)
GPD = GPD.rename(columns={'Country Name':'Country'})
GPD['Country'].replace("Korea, Rep.","South Korea",inplace=True)
GPD['Country'].replace("Iran, Islamic Rep.","Iran",inplace=True)
GPD['Country'].replace("Hong Kong SAR, China","Hong Kong",inplace=True)
GPD = GPD.set_index('Country')
ScimEn = pd.read_excel('scimagojr-3.xlsx')
ScimEn = ScimEn.set_index('Country')
first_merge = pd.merge(energy,GPD,left_index=True, right_index=True,how='outer')
result = pd.merge(ScimEn, first_merge,left_index=True, right_index=True,how='outer')
result.sort_values(by=['Rank'], inplace=True)
number = result.shape[0]-15
number
# Out:
# 303

# %%
result = result[result['Rank']<=15]
result.sort_values(by=['Rank'])
years = np.arange(2006,2016).astype(str)
result['ave']= result[years].mean(axis=1)
result['ave']
# Out:
# Country
# China                 6.348609e+12
# United States         1.536434e+13
# Japan                 5.542208e+12
# United Kingdom        2.487907e+12
# Russian Federation    1.565459e+12
# Canada                1.660647e+12
# Germany               3.493025e+12
# India                 1.769297e+12
# France                2.681725e+12
# South Korea           1.106715e+12
# Italy                 2.120175e+12
# Spain                 1.418078e+12
# Iran                  4.441558e+11
# Australia             1.164043e+12
# Brazil                2.189794e+12
# Name: ave, dtype: float64

# %%
se_country = result[result['Rank']==6]
number = abs(se_country['2015']-se_country['2006'])
number
# Out:
# Country
# Canada    2.281399e+11
# dtype: float64

# %%
avg_energy= np.mean(result['Energy Supply per Capita'])
avg_energy
# Out:
# 157.6

# %%
maxim_re = (result['% Renewable'].idxmax(),result['% Renewable'].max())
maxim_re
# Out:
# ('Brazil', 69.64803)

# %%
result['ratio']= result['Self-citations']/result['Citations']
maxim_self = (result['ratio'].idxmax(),result['ratio'].max())
maxim_self
# Out:
# ('China', 0.6893126179389422)

# %%
result['estimate'] =  result['Energy Supply']//result['Energy Supply per Capita']
third = result['estimate'].sort_values()
result_num=(result[result['estimate']==third[-3]].index[0],third[-3])
result_num
# Out:
# ('United States', 317615384.0)

# %%
result['PopEst'] = result['Energy Supply'] / result['Energy Supply per Capita']
result['Citable docs per Person'] = result['Citable documents'] / result['PopEst']
correlation = result.corr()
correlation.loc['Citable docs per Person', 'Energy Supply per Capita']
# Out:
# 0.7940010435442943

# %%
result['median % Renewable'] = result['% Renewable'].median()
result['Marks'] =  result['% Renewable'] >= result['median % Renewable']
result['Marks'].sort_values(ascending=True)
# Out:
# Country
# United States         False
# Japan                 False
# United Kingdom        False
# India                 False
# South Korea           False
# Iran                  False
# Australia             False
# China                  True
# Russian Federation     True
# Canada                 True
# Germany                True
# France                 True
# Italy                  True
# Spain                  True
# Brazil                 True
# Name: Marks, dtype: bool
